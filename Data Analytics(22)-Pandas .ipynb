# %% [markdown]
# #### Day-1 (07-09-2026)

# %% [markdown]
# # PANDAS

# %% [raw]
# # Def : Pandas is a  Open  Source  library designed for Data Manipulation and Analysis.
# # Pandas is designed over the Numpy.

# %% [markdown]
# # Important list of operation in pandas

# %% [raw]
# 1. Data Structure creation  (Series  (ID array) , DataFrame (2d arrary))
# 2. Data  input and output (CSV, EXCEL, SQL , JSON)
# 3. Understanding the Dataset (head, tail , dtype....)
# 4. Data filtering  and indexing (loc, iloc,where()....)
# 5. Handi=ling of Missing values(NaN/NULL)
# 6. Removing Duplicate values
# 7. Handling inconsistant data
# 8. Data Transformation using apply(), map()
# 9. Aggregation and grouping
# 10. Time series operations
# 11. Basic Data Visualization

# %% [markdown]
# # Importing  and installation of pandas

# %% [raw]
# # pip install pandas
# # Above command  can  create problem with old numpy version
# # conda insatll pandas
# 3 conda commmand will update numpy also  with pandas . so no issue

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# # 1. Data Structure creation (Series (1D array), DataFrame (2D array))

# %% [markdown]
# ### Series(1D array)

# %%
# Create  Series
ser1 = pd.Series()
print(ser1)               # we use series function
# Out:
# Series([], dtype: object)

# %%
# convert  the list to series
list1 = [10, 20, 30, 40, 50]
ser2 = pd.Series(list1)
print(ser2)
print(type(ser2))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
# convert  the list to series 
# hetroginous elements
# in pandas strings are represented as object
# IMP: In series ,all elements have the same datatype
list1 = [10, 20, 30, 40, 50, "Hello"]
ser2 = pd.Series(list1)
print(ser2)
print(type(ser2))
# Out:
# 0       10
# 1       20
# 2       30
# 3       40
# 4       50
# 5    Hello
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
# Convert tuple to Series
tuple1 = (10, 20, 30, 40, 50)
ser2 = pd.Series(tuple1)
print(ser2)
print(type(ser2))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
tuple1 = (10, 20, 30, 40, 50)
ser2 = pd.Series(tuple1)
print(ser2)
print(type(ser2))
print(ser2[2])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# <class 'pandas.core.series.Series'>
# 30

# %%
tuple1 = (10, 20, 30, 40, 50)
ser2 = pd.Series(tuple1)
print(ser2)
print(type(ser2))
print(ser2[2])
print(ser2[-2])

# In Pandas Series , direct negative indexing not allowed.

# %%
# Set cannot be converted  to pandas series
# Set i unordered and series is ordered, so no conversion
set1 = {10, 20, 30, 40, 50}
ser2 = pd.Series(set1)
print(ser2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Set cannot be converted  to pandas series
#       2 set1 = {10, 20, 30, 40, 50}
# ----> 3 ser2 = pd.Series(set1)
#       4 print(ser2)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:587, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     585         data = data.copy()
#     586 else:
# --> 587     data = sanitize_array(data, index, dtype, copy)
#     589     manager = _get_option("mode.data_manager", silent=True)
#     590     if manager == "block":
#
# File ~\anaconda3\Lib\site-packages\pandas\core\construction.py:639, in sanitize_array(data, index, dtype, copy, allow_2d)
#     630     return sanitize_array(
#     631         data,
#     632         index=index,
#    (...)    635         allow_2d=allow_2d,
#     636     )
#     638 else:
# --> 639     _sanitize_non_ordered(data)
#     640     # materialize e.g. generators, convert e.g. tuples, abc.ValueView
#     641     data = list(data)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\construction.py:690, in _sanitize_non_ordered(data)
#     686 """
#     687 Raise only for unordered sets, e.g., not for dict_keys
#     688 """
#     689 if isinstance(data, (set, frozenset)):
# --> 690     raise TypeError(f"'{type(data).__name__}' type is unordered")
#
# TypeError: 'set' type is unordered

# %%
# Convert the numpy array into Series

import numpy as np

arr1 = np.array([10, 20, 30, 40, 50])
print(arr1, type(arr1))
# Out:
# [10 20 30 40 50] <class 'numpy.ndarray'>

# %%
import numpy as np

arr1 = np.array([10, 20, 30, 40, 50])
print(arr1, type(arr1))
ser3 = pd.Series(arr1)
print(arr1, type(ser1))
# Out:
# [10 20 30 40 50] <class 'numpy.ndarray'>
# [10 20 30 40 50] <class 'pandas.core.series.Series'>

# %%
import numpy as np

arr1 = np.array([10, 20, 30, 40, 50])
print(arr1, type(arr1))
ser3 = pd.Series(arr1 , index = ['a' , 'b', 'c', 'd', 'e'])
print(ser3, type(ser3))
print(ser3['a'])
# Out:
# [10 20 30 40 50] <class 'numpy.ndarray'>
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64 <class 'pandas.core.series.Series'>
# 10

# %%
# Update operation on series
ser2[3] = 100000

# insert new value
ser2[5] = 2000
ser2['a'] = 5000
ser2[60] = 7000
ser2[3.4] = 9000
print(ser2)
# Out:
# 0          10
# 2          30
# 3      100000
# 4          50
# 5        2000
# a        5000
# 60       7000
# 3.4      9000
# dtype: int64

# %%
# delete elements from  series
ser2 = ser2.drop(1)
ser2
# Out:
# 0          10
# 2          30
# 3      100000
# 4          50
# 5        2000
# a        5000
# 60       7000
# 3.4      9000
# dtype: int64

# %% [markdown]
# ##### Day: 08/09/2026

# %% [markdown]
# # Data Frame is a 2D array , store data in from of matrix.

# %%
import pandas as pd

# %%
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# converting list to data frame 
fruits_list = ["AratiPandu", "MamadiPandu", "KamalaPandu", "DrakshaPandu"]
df = pd.DataFrame(fruits_list, columns = ["Fruit Name"])
print(df)
# Out:
#      Fruit Name
# 0    AratiPandu
# 1   MamadiPandu
# 2   KamalaPandu
# 3  DrakshaPandu

# %%
fruits_list = ["AratiPandu", "MamadiPandu", "KamalaPandu", "DrakshaPandu"]
df = pd.DataFrame(fruits_list, columns = ["Fruit Name"])
df
# Out:
#      Fruit Name
# 0    AratiPandu
# 1   MamadiPandu
# 2   KamalaPandu
# 3  DrakshaPandu

# %%
# converting 2D list DataFrame
fruits_list = [["AratiPandu",40], ["MamadiPandu",1000], ["KamalaPandu",10], ["DrakshaPandu",120]]
df = pd.DataFrame(fruits_list, columns = ["Fruit Name", "Price"])
df
# Out:
#      Fruit Name  Price
# 0    AratiPandu     40
# 1   MamadiPandu   1000
# 2   KamalaPandu     10
# 3  DrakshaPandu    120

# %%
# created 3 columns dataframe(list of list)
fruits_list = [["AratiPandu",40,100], ["MamadiPandu",1000,200], ["KamalaPandu",10,1000], ["DrakshaPandu",120,100]]
df = pd.DataFrame(fruits_list, columns = ["Fruit Name", "Price", "Discount"])
df
# Out:
#      Fruit Name  Price  Discount
# 0    AratiPandu     40       100
# 1   MamadiPandu   1000       200
# 2   KamalaPandu     10      1000
# 3  DrakshaPandu    120       100

# %%
# created 3 columns dataframe(list of tuple)
fruits_list = [("AratiPandu",40,100), ("MamadiPandu",1000,200), ("KamalaPandu",10,1000), ("DrakshaPandu",120,-100)]
df = pd.DataFrame(fruits_list, columns = ["Fruit Name", "Price", "Discount"])
df
# Out:
#      Fruit Name  Price  Discount
# 0    AratiPandu     40       100
# 1   MamadiPandu   1000       200
# 2   KamalaPandu     10      1000
# 3  DrakshaPandu    120      -100

# %%
# creating DataFrame from dictionary
student_data = {
    "Name" : ["Shiva", "Niranjan", "Suresh", "Akash", "Lahari", "Rakesh"],
    "Salary" : [40,50,60,15,25,100],
    "Study_time" : [12,14, 16, 1, 5, 24]
}
df1 = pd.DataFrame(student_data)
df1
# Out:
#        Name  Salary  Study_time
# 0     Shiva      40          12
# 1  Niranjan      50          14
# 2    Suresh      60          16
# 3     Akash      15           1
# 4    Lahari      25           5
# 5    Rakesh     100          24

# %%
# convert the set of tuple into DataFrame
fruits_list = [("AratiPandu",40,100), ("MamadiPandu",1000,200), ("KamalaPandu",10,1000), ("DrakshaPandu",120,-100)]
df = pd.DataFrame(fruits_list, columns = ["Fruit Name", "Price", "Discount"])
df
# Out:
#      Fruit Name  Price  Discount
# 0    AratiPandu     40       100
# 1   MamadiPandu   1000       200
# 2   KamalaPandu     10      1000
# 3  DrakshaPandu    120      -100

# %%
# Creating DataFrame from set of set 
# In set, we cannot store the mutable items
# In set, only immutable items   can be store
fruits_list = {{"AratiPandu", 40, 100} , {"MamadiPandu",1000,200}, {"KamalaPandu",10,1000}, {"DrakshPandu",120,-100}}
df = pd.DataFrame(fruits_list, columns = ["Fruit Name", "Price", "Discount"])
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       1 # Creating DataFrame from set of set
#       2 # In set, we cannot store the mutable items
#       3 # In set, only immutable items   can be store
# ----> 4 fruits_list = {{"AratiPandu", 40, 100} , {"MamadiPandu",1000,200}, {"KamalaPandu",10,1000}, {"DrakshPandu",120,-100}}
#       5 df = pd.DataFrame(fruits_list, columns = ["Fruit Name", "Price", "Discount"])
#       6 df
#
# TypeError: unhashable type: 'set'

# %%
# Creating DataFrame from set of list 

fruits_list = {["AratiPandu", 40, 100] , ["MamadiPandu",1000,200], ["KamalaPandu",10,1000], ["DrakshPandu",120,-100]}
df = pd.DataFrame(fruits_list, columns = ["Fruit Name", "Price", "Discount"])
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 # Creating DataFrame from set of list
# ----> 3 fruits_list = {["AratiPandu", 40, 100] , ["MamadiPandu",1000,200], ["KamalaPandu",10,1000], ["DrakshPandu",120,-100]}
#       4 df = pd.DataFrame(fruits_list, columns = ["Fruit Name", "Price", "Discount"])
#       5 df
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# ## 2.Data input and output (CSV,EXCEL,SQL,JSON)

# %%
# importing data from CSV file

import os 
os.getcwd()
# Out:
# 'C:\\Users\\gurushankar'

# %%
# import a CSV file as DataFrame
df_csv = pd.read_csv("CSV_data.csv")
df_csv
# Out:
#        Name   Age         Profession  Salary                    Favorite Quote
# 0      John  25.0  Software Engineer   80000            Keep calm and code on!
# 1     Alice   NaN             Doctor  120000           Trust me, I'm a doctor!
# 2     Rocky   NaN              Boxer   50000                 Eye of the tiger!
# 3  Sherlock  40.0          Detective  150000  It's elementary, my dear Watson.
# 4  Mr. Bean  50.0           Comedian   10000                   Why so serious?
# 5  Mr. Bean  50.0           Comedian   10000                   Why so serious?

# %%
# import excel file as a DataFrame
df_excel=pd.read_excel("Excel_data.xlsx")
df_excel
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count
# 0      1     olivia  23.0            Teacher  184518                        0
# 1      2  sophia     20.0              Boxer  119572                        2
# 2      3       jake  38.0          Scientist  174897                        1
# 3      4      Rocky  56.0               Chef  117920                        2
# 4      4      Rocky  56.0               Chef  117920                        1
# ..   ...        ...   ...                ...     ...                      ...
# 495  496       John  45.0              Boxer  137929                        0
# 496  497   Sherlock  46.0              Boxer   39870                        6
# 497  498   Sherlock  47.0          Detective  165951                        5
# 498  499     Olivia  55.0           Comedian  192618                        5
# 499  500   Sherlock  59.0  Software Engineer  194886                       28
#
# [500 rows x 6 columns]

# %%
# export the  data back to csv  and excel file
df_csv.to_excel("Da22_excel.xlsx",index=False)
df_excel.to_csv("Da22_CSV.csv",index=False)

# %%
day-3

# %%
df_excel
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count
# 0      1     olivia  23.0            Teacher  184518                        0
# 1      2  sophia     20.0              Boxer  119572                        2
# 2      3       jake  38.0          Scientist  174897                        1
# 3      4      Rocky  56.0               Chef  117920                        2
# 4      4      Rocky  56.0               Chef  117920                        1
# ..   ...        ...   ...                ...     ...                      ...
# 495  496       John  45.0              Boxer  137929                        0
# 496  497   Sherlock  46.0              Boxer   39870                        6
# 497  498   Sherlock  47.0          Detective  165951                        5
# 498  499     Olivia  55.0           Comedian  192618                        5
# 499  500   Sherlock  59.0  Software Engineer  194886                       28
#
# [500 rows x 6 columns]

# %%
# reading and writing inn a sql
import sqlite3
# creating a database if it don't exist
conn = sqlite3.connect("shiva_da22.db")

# %%
# creating a table and strating the dataframe data inside it
df_excel.to_sql("prof_table",conn,if_exists='replace')
# Out:
# 500

# %%
# reading the data from sql table to df
df =pd.read_sql('select * from prof_table',conn)
df
# Out:
#      index   ID       Name   Age         Profession  salary  \
# 0        0    1     olivia  23.0            Teacher  184518
# 1        1    2  sophia     20.0              Boxer  119572
# 2        2    3       jake  38.0          Scientist  174897
# 3        3    4      Rocky  56.0               Chef  117920
# 4        4    4      Rocky  56.0               Chef  117920
# ..     ...  ...        ...   ...                ...     ...
# 495    495  496       John  45.0              Boxer  137929
# 496    496  497   Sherlock  46.0              Boxer   39870
# 497    497  498   Sherlock  47.0          Detective  165951
# 498    498  499     Olivia  55.0           Comedian  192618
# 499    499  500   Sherlock  59.0  Software Engineer  194886
#
#      Marriage_proposal_count
# 0                          0
# 1                          2
# 2                          1
# 3                          2
# 4                          1
# ..                       ...
# 495                        0
# 496                        6
# 497                        5
# 498                        5
# 499                       28
#
# [500 rows x 7 columns]

# %%
# impoting data from JSON file 
df_json = pd.read_json('json_data.json')
df_json
# Out:
#    order_id customer_name       food_item     delivery_boy  rating  \
# 0       101          Ramu     Idli Burger    Speed Shankar       5
# 1       102         Priya      Dosa Pizza      Late Laxman       2
# 2       103        Dinesh   Paneer Sambar     Turbo Thambi       4
# 3       104         Lachu     Mango Maggi      Round Robin       1
# 4       105         Meena  Coconut Coffee  Careless Kannan       3
#
#    delivery_time_min
# 0                 15
# 1                 60
# 2                 25
# 3                 90
# 4                 40

# %%
# exporting data from dataframe to json file 
df_json.to_json('food_data.json')

# %% [markdown]
# ## 3. understading the data set (head,tail,dtype,.....)

# %%
# view the data with head(),tail() functions
# head(x) function is used to accessing top x records
# head() by default shows the 5 records
df_excel.head(10)
# Out:
#    ID       Name   Age   Profession  salary  Marriage_proposal_count
# 0   1     olivia  23.0      Teacher  184518                        0
# 1   2  sophia     20.0        Boxer  119572                        2
# 2   3       jake  38.0    Scientist  174897                        1
# 3   4      Rocky  56.0         Chef  117920                        2
# 4   4      Rocky  56.0         Chef  117920                        1
# 5   4      Rocky  56.0         Chef  117920                        3
# 6   4      Rocky  56.0         Chef  117920                       11
# 7   4      Rocky  56.0         Chef  117920                        2
# 8   4      Rocky  56.0         Chef  117920                        2
# 9   4      Rocky  56.0         Chef  117920                        3

# %%
# tail(x) function is used to accessing bottom x records
# tail() by default shows the 5 records
df_excel.tail(10)
# Out:
#       ID      Name   Age         Profession  salary  Marriage_proposal_count
# 490  491      John  57.0              Pilot  154180                        0
# 491  492      Emma  34.0             Artist  145412                        1
# 492  493      John  55.0             Artist   57720                        2
# 493  494    Sophia  39.0             Doctor  174500                        0
# 494  495     Rocky  27.0             Doctor   46975                        0
# 495  496      John  45.0              Boxer  137929                        0
# 496  497  Sherlock  46.0              Boxer   39870                        6
# 497  498  Sherlock  47.0          Detective  165951                        5
# 498  499    Olivia  55.0           Comedian  192618                        5
# 499  500  Sherlock  59.0  Software Engineer  194886                       28

# %%
df_excel.shape
# Out:
# (500, 6)

# %%
# shows the single column
df_excel['Name']
# Out:
# 0         olivia
# 1      sophia
# 2           jake
# 3          Rocky
# 4          Rocky
#          ...
# 495         John
# 496     Sherlock
# 497     Sherlock
# 498       Olivia
# 499     Sherlock
# Name: Name, Length: 500, dtype: object

# %%
df_excel.Name
# Out:
# 0         olivia
# 1      sophia
# 2           jake
# 3          Rocky
# 4          Rocky
#          ...
# 495         John
# 496     Sherlock
# 497     Sherlock
# 498       Olivia
# 499     Sherlock
# Name: Name, Length: 500, dtype: object

# %%
df_excel['Profession']
# Out:
# 0                Teacher
# 1                  Boxer
# 2              Scientist
# 3                   Chef
# 4                   Chef
#              ...
# 495                Boxer
# 496                Boxer
# 497            Detective
# 498             Comedian
# 499    Software Engineer
# Name: Profession, Length: 500, dtype: object

# %%
df_excel[['Name','Profession']]
# Out:
#           Name         Profession
# 0       olivia            Teacher
# 1    sophia                 Boxer
# 2         jake          Scientist
# 3        Rocky               Chef
# 4        Rocky               Chef
# ..         ...                ...
# 495       John              Boxer
# 496   Sherlock              Boxer
# 497   Sherlock          Detective
# 498     Olivia           Comedian
# 499   Sherlock  Software Engineer
#
# [500 rows x 2 columns]

# %%
# printing multiple columns
df_excel[['Name','Profession','salary']]
# Out:
#           Name         Profession  salary
# 0       olivia            Teacher  184518
# 1    sophia                 Boxer  119572
# 2         jake          Scientist  174897
# 3        Rocky               Chef  117920
# 4        Rocky               Chef  117920
# ..         ...                ...     ...
# 495       John              Boxer  137929
# 496   Sherlock              Boxer   39870
# 497   Sherlock          Detective  165951
# 498     Olivia           Comedian  192618
# 499   Sherlock  Software Engineer  194886
#
# [500 rows x 3 columns]

# %%
df_rename=df_excel.rename(columns ={'Name':'peru','Profession':'Vruthi'})
df_rename
# Out:
#       ID       peru   Age             Vruthi  salary  Marriage_proposal_count
# 0      1     olivia  23.0            Teacher  184518                        0
# 1      2  sophia     20.0              Boxer  119572                        2
# 2      3       jake  38.0          Scientist  174897                        1
# 3      4      Rocky  56.0               Chef  117920                        2
# 4      4      Rocky  56.0               Chef  117920                        1
# ..   ...        ...   ...                ...     ...                      ...
# 495  496       John  45.0              Boxer  137929                        0
# 496  497   Sherlock  46.0              Boxer   39870                        6
# 497  498   Sherlock  47.0          Detective  165951                        5
# 498  499     Olivia  55.0           Comedian  192618                        5
# 499  500   Sherlock  59.0  Software Engineer  194886                       28
#
# [500 rows x 6 columns]

# %%
# print all the column names 
df_rename.columns
# Out:
# Index(['ID', 'peru', 'Age', 'Vruthi', 'salary', 'Marriage_proposal_count'], dtype='object')

# %% [markdown]
# ## creating new column in the dataframe

# %%
#  here rank() function is a pandas function
# rank() function is giving rank-1 to minmum salary and higher rank value to higher salary
df_excel['rank'] = df_excel['salary'].rank(ascending =False)
df_excel.sort_values('rank')
# Out:
#       ID      Name   Age         Profession  salary  Marriage_proposal_count  \
# 436  437  Sherlock  52.0              Boxer  199529                        3
# 65    66      Emma  57.0              Pilot  199317                        1
# 132  133     Rocky  31.0             Doctor  198978                        8
# 167  168  Mr. Bean  44.0           Comedian  198847                       14
# 474  475    Sophia  30.0             Doctor  198653                        1
# ..   ...       ...   ...                ...     ...                      ...
# 284  285      Jake  46.0          Detective   30971                        1
# 329  330  Sherlock  40.0          Scientist   30905                        0
# 398  399     Rocky  25.0          Scientist   30659                        5
# 90    91     Rocky  43.0  Software Engineer   30407                       10
# 213  214  Sherlock  21.0               Chef   30164                        2
#
#       rank
# 436    1.0
# 65     2.0
# 132    3.0
# 167    4.0
# 474    5.0
# ..     ...
# 284  496.0
# 329  497.0
# 398  498.0
# 90   499.0
# 213  500.0
#
# [500 rows x 7 columns]

# %%
# droping the column
# axis =1 : delete the column
# axis =0 : delete the row
df_excel=df_excel.drop(['rank'],axis=1)
df_excel
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count
# 0      1     olivia  23.0            Teacher  184518                        0
# 1      2  sophia     20.0              Boxer  119572                        2
# 2      3       jake  38.0          Scientist  174897                        1
# 3      4      Rocky  56.0               Chef  117920                        2
# 4      4      Rocky  56.0               Chef  117920                        1
# ..   ...        ...   ...                ...     ...                      ...
# 495  496       John  45.0              Boxer  137929                        0
# 496  497   Sherlock  46.0              Boxer   39870                        6
# 497  498   Sherlock  47.0          Detective  165951                        5
# 498  499     Olivia  55.0           Comedian  192618                        5
# 499  500   Sherlock  59.0  Software Engineer  194886                       28
#
# [500 rows x 6 columns]

# %% [markdown]
# ## Replace a value in dataframe

# %%
df=df_excel
df
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count
# 0      1     olivia  23.0            Teacher  184518                        0
# 1      2  sophia     20.0              Boxer  119572                        2
# 2      3       jake  38.0          Scientist  174897                        1
# 3      4      Rocky  56.0               Chef  117920                        2
# 4      4      Rocky  56.0               Chef  117920                        1
# ..   ...        ...   ...                ...     ...                      ...
# 495  496       John  45.0              Boxer  137929                        0
# 496  497   Sherlock  46.0              Boxer   39870                        6
# 497  498   Sherlock  47.0          Detective  165951                        5
# 498  499     Olivia  55.0           Comedian  192618                        5
# 499  500   Sherlock  59.0  Software Engineer  194886                       28
#
# [500 rows x 6 columns]

# %%
# repalce all the olivia in name column with cherry
df['Name'] = df.Name.replace('olivia','cherry')
df
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count
# 0      1     cherry  23.0            Teacher  184518                        0
# 1      2  sophia     20.0              Boxer  119572                        2
# 2      3       jake  38.0          Scientist  174897                        1
# 3      4      Rocky  56.0               Chef  117920                        2
# 4      4      Rocky  56.0               Chef  117920                        1
# ..   ...        ...   ...                ...     ...                      ...
# 495  496       John  45.0              Boxer  137929                        0
# 496  497   Sherlock  46.0              Boxer   39870                        6
# 497  498   Sherlock  47.0          Detective  165951                        5
# 498  499     Olivia  55.0           Comedian  192618                        5
# 499  500   Sherlock  59.0  Software Engineer  194886                       28
#
# [500 rows x 6 columns]

# %%
# replacing multiple values
df['Name'] = df.Name.replace({'cherry':'shiva','Rocky':'vedhu'})

# replacing values from multiple columns together
# inplace = true : to perform the task without taking extra space  

df= df.replace({'shiva':'AA','Teacher':'hero'})   # or df.replace({'shiva':'AA','Teacher':'hero'}, inplace  = True)
df
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count
# 0      1         AA  23.0               hero  184518                        0
# 1      2  sophia     20.0              Boxer  119572                        2
# 2      3       jake  38.0          Scientist  174897                        1
# 3      4      vedhu  56.0               Chef  117920                        2
# 4      4      vedhu  56.0               Chef  117920                        1
# ..   ...        ...   ...                ...     ...                      ...
# 495  496       John  45.0              Boxer  137929                        0
# 496  497   Sherlock  46.0              Boxer   39870                        6
# 497  498   Sherlock  47.0          Detective  165951                        5
# 498  499     Olivia  55.0           Comedian  192618                        5
# 499  500   Sherlock  59.0  Software Engineer  194886                       28
#
# [500 rows x 6 columns]

# %%
# dtypes are used to check the datatype of all the columns
# in pandas, strings are represented with object
df.dtypes
# Out:
# ID                           int64
# Name                        object
# Age                        float64
# Profession                  object
# salary                       int64
# Marriage_proposal_count      int64
# dtype: object

# %% [markdown]
# ## convert datatype

# %%
# 
df['Name'] = df['Name'].astype('string')
df.dtypes
# Out:
# ID                                  int64
# Name                       string[python]
# Age                               float64
# Profession                         object
# salary                              int64
# Marriage_proposal_count             int64
# dtype: object

# %%
df['salary'] = df['salary'].astype('float')
df.dtypes
# Out:
# ID                                  int64
# Name                       string[python]
# Age                               float64
# Profession                         object
# salary                            float64
# Marriage_proposal_count             int64
# dtype: object

# %%
# printing the columns which is having specific datatypes numarical columns
df.select_dtypes(include = ['int','float'])
# Out:
#       ID   Age    salary  Marriage_proposal_count
# 0      1  23.0  184518.0                        0
# 1      2  20.0  119572.0                        2
# 2      3  38.0  174897.0                        1
# 3      4  56.0  117920.0                        2
# 4      4  56.0  117920.0                        1
# ..   ...   ...       ...                      ...
# 495  496  45.0  137929.0                        0
# 496  497  46.0   39870.0                        6
# 497  498  47.0  165951.0                        5
# 498  499  55.0  192618.0                        5
# 499  500  59.0  194886.0                       28
#
# [500 rows x 4 columns]

# %%
# string columns or catagrical columns
df.select_dtypes(include = ['string','object'])
# Out:
#           Name         Profession
# 0           AA               hero
# 1    sophia                 Boxer
# 2         jake          Scientist
# 3        vedhu               Chef
# 4        vedhu               Chef
# ..         ...                ...
# 495       John              Boxer
# 496   Sherlock              Boxer
# 497   Sherlock          Detective
# 498     Olivia           Comedian
# 499   Sherlock  Software Engineer
#
# [500 rows x 2 columns]

# %%
# give name of all the columns which are string type 
df.select_dtypes(include = ['string','object']).columns
# Out:
# Index(['Name', 'Profession'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       500 non-null    int64
#  1   Name                     500 non-null    string
#  2   Age                      492 non-null    float64
#  3   Profession               500 non-null    object
#  4   salary                   500 non-null    float64
#  5   Marriage_proposal_count  500 non-null    int64
# dtypes: float64(2), int64(2), object(1), string(1)
# memory usage: 23.6+ KB

# %%
# query: print all the unique profession
df.Profession.unique()
# Out:
# array(['hero', '      Boxer', 'Scientist', 'Chef', 'Doctor', 'Artist',
#        'Comedian', 'Software Engineer', 'Detective', 'Pilot'],
#       dtype=object)

# %%
# nunique is telling number if unique in this profession 
df.Profession.nunique()
# Out:
# 10

# %%
# query: how many people are boxer in this dataset
df.Profession.value_counts()
# Out:
# Profession
# Chef                 58
# Scientist            54
#       Boxer          53
# Pilot                53
# Comedian             52
# Software Engineer    51
# Doctor               48
# hero                 45
# Detective            45
# Artist               41
# Name: count, dtype: int64

# %%
# describe statistical information 
# bydefault , describe() works on numerical columns
df.describe()
# Out:
#                ID         Age         salary  Marriage_proposal_count
# count  500.000000  492.000000     500.000000                500.00000
# mean   250.458000   40.810976  115602.828000                  4.02600
# std    144.552978   11.790553   49404.366846                  5.25362
# min      1.000000   20.000000   30164.000000                  0.00000
# 25%    125.750000   31.000000   74964.750000                  1.00000
# 50%    250.500000   40.500000  117920.000000                  3.00000
# 75%    375.250000   51.000000  160579.500000                  5.00000
# max    500.000000   60.000000  199529.000000                 40.00000

# %%
df.describe(include ='int')
# Out:
#                ID  Marriage_proposal_count
# count  500.000000                500.00000
# mean   250.458000                  4.02600
# std    144.552978                  5.25362
# min      1.000000                  0.00000
# 25%    125.750000                  1.00000
# 50%    250.500000                  3.00000
# 75%    375.250000                  5.00000
# max    500.000000                 40.00000

# %%
# describing string/object columns
df.describe(include =['object','string'])
# Out:
#             Name Profession
# count        500        500
# unique        13         10
# top     Sherlock       Chef
# freq          61         58

# %% [markdown]
# ### 4. data flitering and indexing (loc,iloc,where()....)

# %%
# fliter all the recordes where salary > 100000
df[df.salary>100000]
# Out:
#       ID       Name   Age         Profession    salary  \
# 0      1         AA  23.0               hero  184518.0
# 1      2  sophia     20.0              Boxer  119572.0
# 2      3       jake  38.0          Scientist  174897.0
# 3      4      vedhu  56.0               Chef  117920.0
# 4      4      vedhu  56.0               Chef  117920.0
# ..   ...        ...   ...                ...       ...
# 493  494     Sophia  39.0             Doctor  174500.0
# 495  496       John  45.0              Boxer  137929.0
# 497  498   Sherlock  47.0          Detective  165951.0
# 498  499     Olivia  55.0           Comedian  192618.0
# 499  500   Sherlock  59.0  Software Engineer  194886.0
#
#      Marriage_proposal_count
# 0                          0
# 1                          2
# 2                          1
# 3                          2
# 4                          1
# ..                       ...
# 493                        0
# 495                        0
# 497                        5
# 498                        5
# 499                       28
#
# [304 rows x 6 columns]

# %%
# fliter all the records where salary >100000 & salary < 15000000
df[(df.salary < 100000) & (df.salary < 150000)]
# Out:
#       ID      Name   Age         Profession   salary  Marriage_proposal_count
# 10    11     vedhu   NaN             Doctor  75543.0                        5
# 13    14      John  46.0             Artist  43078.0                       12
# 15    16  Sherlock  30.0              Boxer  57774.0                        0
# 23    24  Sherlock  42.0              Boxer  92995.0                        2
# 26    27     Alice  48.0              Pilot  99949.0                        4
# ..   ...       ...   ...                ...      ...                      ...
# 488  489      Emma  21.0  Software Engineer  92013.0                        2
# 489  490      John  56.0          Scientist  41192.0                        7
# 492  493      John  55.0             Artist  57720.0                        2
# 494  495     vedhu  27.0             Doctor  46975.0                        0
# 496  497  Sherlock  46.0              Boxer  39870.0                        6
#
# [196 rows x 6 columns]

# %%
# query: fliter all the records where salary >100000 /(OR)(salary < 100000
df[(df.salary < 100000) | (df.salary > 150000)]
# Out:
#       ID      Name   Age         Profession    salary  Marriage_proposal_count
# 0      1        AA  23.0               hero  184518.0                        0
# 2      3      jake  38.0          Scientist  174897.0                        1
# 10    11     vedhu   NaN             Doctor   75543.0                        5
# 11    12      Jake   NaN             Artist  174780.0                        5
# 13    14      John  46.0             Artist   43078.0                       12
# ..   ...       ...   ...                ...       ...                      ...
# 494  495     vedhu  27.0             Doctor   46975.0                        0
# 496  497  Sherlock  46.0              Boxer   39870.0                        6
# 497  498  Sherlock  47.0          Detective  165951.0                        5
# 498  499    Olivia  55.0           Comedian  192618.0                        5
# 499  500  Sherlock  59.0  Software Engineer  194886.0                       28
#
# [349 rows x 6 columns]

# %%
# query: find the person record who is getting highest salary.
# hint :max()
max(df.salary)
# Out:
# 199529.0

# %%
df.salary.max()
# Out:
# 199529.0

# %% [markdown]
# ## day-5 11/09/2026

# %%
# query: find the person record who is getting highest salary.
# hint :max()
import pandas as pd
df = pd.read_excel("Excel_data.xlsx")
df
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count
# 0      1     olivia  23.0            Teacher  184518                        0
# 1      2  sophia     20.0              Boxer  119572                        2
# 2      3       jake  38.0          Scientist  174897                        1
# 3      4      Rocky  56.0               Chef  117920                        2
# 4      4      Rocky  56.0               Chef  117920                        1
# ..   ...        ...   ...                ...     ...                      ...
# 495  496       John  45.0              Boxer  137929                        0
# 496  497   Sherlock  46.0              Boxer   39870                        6
# 497  498   Sherlock  47.0          Detective  165951                        5
# 498  499     Olivia  55.0           Comedian  192618                        5
# 499  500   Sherlock  59.0  Software Engineer  194886                       28
#
# [500 rows x 6 columns]

# %%
# query: find the person record who is getting highest salary.
max(df.salary)
# Out:
# 199529

# %%
df[df.salary > 100000]
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count
# 0      1     olivia  23.0            Teacher  184518                        0
# 1      2  sophia     20.0              Boxer  119572                        2
# 2      3       jake  38.0          Scientist  174897                        1
# 3      4      Rocky  56.0               Chef  117920                        2
# 4      4      Rocky  56.0               Chef  117920                        1
# ..   ...        ...   ...                ...     ...                      ...
# 493  494     Sophia  39.0             Doctor  174500                        0
# 495  496       John  45.0              Boxer  137929                        0
# 497  498   Sherlock  47.0          Detective  165951                        5
# 498  499     Olivia  55.0           Comedian  192618                        5
# 499  500   Sherlock  59.0  Software Engineer  194886                       28
#
# [304 rows x 6 columns]

# %%
df[df.salary == df.salary.max()]
# Out:
#       ID      Name   Age   Profession  salary  Marriage_proposal_count
# 436  437  Sherlock  52.0        Boxer  199529                        3

# %%
# query: find the person record who is getting lowest salary.
# Hint: min
min(df.salary)
# Out:
# 30164

# %%
df.salary == df.salary.min()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: salary, Length: 500, dtype: bool

# %%
df[df.salary == df.salary.min()]
# Out:
#       ID      Name   Age Profession  salary  Marriage_proposal_count
# 213  214  Sherlock  21.0       Chef   30164                        2

# %%
# Query : Print just the  Name, Age, salary of the person having max salary
df[df.salary == df.salary.max()]
# Out:
#       ID      Name   Age   Profession  salary  Marriage_proposal_count
# 436  437  Sherlock  52.0        Boxer  199529                        3

# %%
df[df.salary == df.salary.max()].Name
# Out:
# 436    Sherlock
# Name: Name, dtype: object

# %%
# Query : print just the Name Age salary of the person having max salary
df[df.salary == df.salary.max()][["Name", "Age","salary"]]
# Out:
#          Name   Age  salary
# 436  Sherlock  52.0  199529

# %%
df[["Name","Age"]]
# Out:
#           Name   Age
# 0       olivia  23.0
# 1    sophia     20.0
# 2         jake  38.0
# 3        Rocky  56.0
# 4        Rocky  56.0
# ..         ...   ...
# 495       John  45.0
# 496   Sherlock  46.0
# 497   Sherlock  47.0
# 498     Olivia  55.0
# 499   Sherlock  59.0
#
# [500 rows x 2 columns]

# %%
df["Age"]
# Out:
# 0      23.0
# 1      20.0
# 2      38.0
# 3      56.0
# 4      56.0
#        ...
# 495    45.0
# 496    46.0
# 497    47.0
# 498    55.0
# 499    59.0
# Name: Age, Length: 500, dtype: float64

# %%
df[["Name", "Age","salary"]]
# Out:
#           Name   Age  salary
# 0       olivia  23.0  184518
# 1    sophia     20.0  119572
# 2         jake  38.0  174897
# 3        Rocky  56.0  117920
# 4        Rocky  56.0  117920
# ..         ...   ...     ...
# 495       John  45.0  137929
# 496   Sherlock  46.0   39870
# 497   Sherlock  47.0  165951
# 498     Olivia  55.0  192618
# 499   Sherlock  59.0  194886
#
# [500 rows x 3 columns]

# %%
### where(): used for filtering the data
# where() function returns NaN in place of those values
# which don't satisfied the condition
df1 = df.copy()

df1 = df1.Age.where(df1.Age > 50)

df1
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3      56.0
# 4      56.0
#        ...
# 495     NaN
# 496     NaN
# 497     NaN
# 498    55.0
# 499    59.0
# Name: Age, Length: 500, dtype: float64

# %%
df1 = df[df.Age > 50].Age

print(df1.to_string(index=False, header=False))
# Out:
# Series([], )

# %%
# if you don't want NaN records
df[df.Age > 50]
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, Profession, salary, Marriage_proposal_count]
# Index: []

# %%
df["salary"]
# Out:
# 0      184518
# 1      119572
# 2      174897
# 3      117920
# 4      117920
#         ...
# 495    137929
# 496     39870
# 497    165951
# 498    192618
# 499    194886
# Name: salary, Length: 500, dtype: int64

# %%
### where(): used for filtering the data
# where() function returns NaN in place of those values
# which don't satisfied the condition
df1 = df.copy()
df1 = df1.Age.where(df1.Age > 50)
df1
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3      56.0
# 4      56.0
#        ...
# 495     NaN
# 496     NaN
# 497     NaN
# 498    55.0
# 499    59.0
# Name: Age, Length: 500, dtype: float64

# %%
df1 = df.copy()

df1 = df1[['Age']].where(df1[['Age']] > 50, 100)

df1
# Out:
#        Age
# 0    100.0
# 1    100.0
# 2    100.0
# 3    100.0
# 4    100.0
# ..     ...
# 495  100.0
# 496  100.0
# 497  100.0
# 498  100.0
# 499  100.0
#
# [500 rows x 1 columns]

# %%
# if you dont want NaN records
df[df.Age > 50]
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, Profession, salary, Marriage_proposal_count]
# Index: []

# %% [markdown]
# ## indexing: loc &  iloc

# %%
# loc & iloc is used for filtering
# these helps to select particualr ROW & COLUMN in the dataframe

# %%
# Query: print records 1 to 4, and columns ID, name, Age Only
df.loc[1:4,'ID': 'Age']   # df.loc[start_row : end_row, col_start : col_end]
# Out:
#    ID       Name   Age
# 1   2  sophia     20.0
# 2   3       jake  38.0
# 3   4      Rocky  56.0
# 4   4      Rocky  56.0

# %% [raw]
# ## INTERVIEW Question
# Q1. What is the difference between loc and iloc?
# A. - In loc columns are passed with their Names but in iloc columns are passed as index
#    - iloc is  easy to use due to index usage
#    - iloc [start_row : end_row-1, col_start : col_end-1]
#    - iloc is ittle faster than the loc

# %%
# Query: Print records 10 to 40 , and columns Name:Profession Only
df.loc[10:40, "Name" : "Profession"]
# Out:
#         Name   Age         Profession
# 10     Rocky   NaN             Doctor
# 11      Jake   NaN             Artist
# 12    Olivia  22.0           Comedian
# 13      John  46.0             Artist
# 14      Jake  40.0               Chef
# 15  Sherlock  30.0              Boxer
# 16      Jake  46.0             Artist
# 17      Jake  53.0  Software Engineer
# 18     Rocky  25.0           Comedian
# 19  Sherlock  40.0          Detective
# 20  Sherlock  40.0          Detective
# 21      John  41.0          Scientist
# 22      John  41.0          Scientist
# 23  Sherlock  42.0              Boxer
# 24    Olivia  60.0          Detective
# 25    Olivia  53.0          Detective
# 26     Alice  48.0              Pilot
# 27  Sherlock  55.0          Scientist
# 28     Alice  21.0               Chef
# 29     Alice  21.0               Chef
# 30     Alice  30.0            Teacher
# 31    Olivia  30.0             Doctor
# 32  Mr. Bean  27.0             Artist
# 33    Olivia  45.0           Comedian
# 34  Sherlock  46.0               Chef
# 35  Mr. Bean  44.0           Comedian
# 36     Rocky  57.0            Teacher
# 37  Mr. Bean  32.0          Scientist
# 38      John  27.0  Software Engineer
# 39    Olivia  60.0  Software Engineer
# 40     Alice  52.0               Chef

# %%
df
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count
# 0      1     olivia  23.0            Teacher  184518                        0
# 1      2  sophia     20.0              Boxer  119572                        2
# 2      3       jake  38.0          Scientist  174897                        1
# 3      4      Rocky  56.0               Chef  117920                        2
# 4      4      Rocky  56.0               Chef  117920                        1
# ..   ...        ...   ...                ...     ...                      ...
# 495  496       John  45.0              Boxer  137929                        0
# 496  497   Sherlock  46.0              Boxer   39870                        6
# 497  498   Sherlock  47.0          Detective  165951                        5
# 498  499     Olivia  55.0           Comedian  192618                        5
# 499  500   Sherlock  59.0  Software Engineer  194886                       28
#
# [500 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Profession', 'salary', 'Marriage_proposal_count'], dtype='object')

# %% [markdown]
# ## iloc

# %%
# Query : print records 1 to 4, and columns ID, name, Age Only
df.iloc[1:5, 0:3]
# Out:
#    ID       Name   Age
# 1   2  sophia     20.0
# 2   3       jake  38.0
# 3   4      Rocky  56.0
# 4   4      Rocky  56.0

# %% [markdown]
# ### 15/09/2026

# %%
import pandas as pd
df = pd.read_excel("Excel_data.xlsx")
df
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count
# 0      1     olivia  23.0            Teacher  184518                        0
# 1      2  sophia     20.0              Boxer  119572                        2
# 2      3       jake  38.0          Scientist  174897                        1
# 3      4      Rocky  56.0               Chef  117920                        2
# 4      4      Rocky  56.0               Chef  117920                        1
# ..   ...        ...   ...                ...     ...                      ...
# 495  496       John  45.0              Boxer  137929                        0
# 496  497   Sherlock  46.0              Boxer   39870                        6
# 497  498   Sherlock  47.0          Detective  165951                        5
# 498  499     Olivia  55.0           Comedian  192618                        5
# 499  500   Sherlock  59.0  Software Engineer  194886                       28
#
# [500 rows x 6 columns]

# %%
df.iloc[0:20, 0:5]
# Out:
#     ID       Name   Age         Profession  salary
# 0    1     olivia  23.0            Teacher  184518
# 1    2  sophia     20.0              Boxer  119572
# 2    3       jake  38.0          Scientist  174897
# 3    4      Rocky  56.0               Chef  117920
# 4    4      Rocky  56.0               Chef  117920
# 5    4      Rocky  56.0               Chef  117920
# 6    4      Rocky  56.0               Chef  117920
# 7    4      Rocky  56.0               Chef  117920
# 8    4      Rocky  56.0               Chef  117920
# 9    4      Rocky  56.0               Chef  117920
# 10  11      Rocky   NaN             Doctor   75543
# 11  12       Jake   NaN             Artist  174780
# 12  13     Olivia  22.0           Comedian  102063
# 13  14       John  46.0             Artist   43078
# 14  15       Jake  40.0               Chef  171553
# 15  16   Sherlock  30.0              Boxer   57774
# 16  17       Jake  46.0             Artist  135907
# 17  18       Jake  53.0  Software Engineer  127117
# 18  19      Rocky  25.0           Comedian  181312
# 19  20   Sherlock  40.0          Detective  118998

# %%
# iloc using step size
df.iloc[0:200:10, 0:5:2]
# Out:
#       ID   Age  salary
# 0      1  23.0  184518
# 10    11   NaN   75543
# 20    21  40.0  118998
# 30    31  30.0   77599
# 40    41  52.0   46535
# 50    51  42.0  105830
# 60    61  37.0  106436
# 70    71  40.0  188182
# 80    81  38.0  125743
# 90    91  43.0   30407
# 100  101  60.0  163578
# 110  111  44.0  165346
# 120  121  43.0   34630
# 130  131  26.0  145227
# 140  141  46.0   61653
# 150  151  60.0  135857
# 160  161  42.0  150873
# 170  171  30.0  139649
# 180  181  32.0  134405
# 190  191  34.0  112912

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Profession', 'salary', 'Marriage_proposal_count'], dtype='object')

# %%
# iloc showing any random columns
# iloc using with specific coumns

df.iloc[0:200:10, [3,1,4]]
# Out:
#             Profession      Name  salary
# 0              Teacher    olivia  184518
# 10              Doctor     Rocky   75543
# 20           Detective  Sherlock  118998
# 30             Teacher     Alice   77599
# 40                Chef     Alice   46535
# 50               Pilot      Liam  105830
# 60               Boxer  Sherlock  106436
# 70               Boxer      Jake  188182
# 80              Artist      Emma  125743
# 90   Software Engineer     Rocky   30407
# 100            Teacher    Olivia  163578
# 110          Scientist      John  165346
# 120               Chef  Mr. Bean   34630
# 130             Artist  Mr. Bean  145227
# 140  Software Engineer      John   61653
# 150          Scientist  Sherlock  135857
# 160             Artist     Rocky  150873
# 170            Teacher  Mr. Bean  139649
# 180          Detective    Sophia  134405
# 190             Artist    Sophia  112912

# %%
df.iloc[:, [3,1,4]]
df.iloc[1, [3,1,4]]
df.iloc[:, [1,1]]
# Out:
#           Name       Name
# 0       olivia     olivia
# 1    sophia     sophia
# 2         jake       jake
# 3        Rocky      Rocky
# 4        Rocky      Rocky
# ..         ...        ...
# 495       John       John
# 496   Sherlock   Sherlock
# 497   Sherlock   Sherlock
# 498     Olivia     Olivia
# 499   Sherlock   Sherlock
#
# [500 rows x 2 columns]

# %%
# iloc using with specific coumns

df.iloc[1,5]
# Out:
# 2

# %%
print(df.iloc[1,5])
# Out:
# 2

# %%
# loc to get age and salary columns
df.loc [0:5, ["Age", "salary"]]
# Out:
#     Age  salary
# 0  23.0  184518
# 1  20.0  119572
# 2  38.0  174897
# 3  56.0  117920
# 4  56.0  117920
# 5  56.0  117920

# %%
# comparison condition inside the loc
df.Age > 50
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 495    False
# 496    False
# 497    False
# 498     True
# 499     True
# Name: Age, Length: 500, dtype: bool

# %%
df[df.Age > 50]
# Out:
#       ID      Name   Age         Profession  salary  Marriage_proposal_count
# 3      4     Rocky  56.0               Chef  117920                        2
# 4      4     Rocky  56.0               Chef  117920                        1
# 5      4     Rocky  56.0               Chef  117920                        3
# 6      4     Rocky  56.0               Chef  117920                       11
# 7      4     Rocky  56.0               Chef  117920                        2
# ..   ...       ...   ...                ...     ...                      ...
# 489  490      John  56.0          Scientist   41192                        7
# 490  491      John  57.0              Pilot  154180                        0
# 492  493      John  55.0             Artist   57720                        2
# 498  499    Olivia  55.0           Comedian  192618                        5
# 499  500  Sherlock  59.0  Software Engineer  194886                       28
#
# [126 rows x 6 columns]

# %%
df.loc[df.Age > 50,["Age","salary"]]
# Out:
#       Age  salary
# 3    56.0  117920
# 4    56.0  117920
# 5    56.0  117920
# 6    56.0  117920
# 7    56.0  117920
# ..    ...     ...
# 489  56.0   41192
# 490  57.0  154180
# 492  55.0   57720
# 498  55.0  192618
# 499  59.0  194886
#
# [126 rows x 2 columns]

# %%
# comparison condition inside the loc
# Saalry of people Age > 50 & Age < 70
df.loc[(df.Age > 50 ) & (df.Age < 70),["Age", "salary"]]
# Out:
#       Age  salary
# 3    56.0  117920
# 4    56.0  117920
# 5    56.0  117920
# 6    56.0  117920
# 7    56.0  117920
# ..    ...     ...
# 489  56.0   41192
# 490  57.0  154180
# 492  55.0   57720
# 498  55.0  192618
# 499  59.0  194886
#
# [126 rows x 2 columns]

# %%
# iloc  don't works with pandas Series
#.values will convert it into numpy array
df.iloc[(df.Age >  50).values, 0:4]
# Out:
#       ID      Name   Age         Profession
# 3      4     Rocky  56.0               Chef
# 4      4     Rocky  56.0               Chef
# 5      4     Rocky  56.0               Chef
# 6      4     Rocky  56.0               Chef
# 7      4     Rocky  56.0               Chef
# ..   ...       ...   ...                ...
# 489  490      John  56.0          Scientist
# 490  491      John  57.0              Pilot
# 492  493      John  55.0             Artist
# 498  499    Olivia  55.0           Comedian
# 499  500  Sherlock  59.0  Software Engineer
#
# [126 rows x 4 columns]

# %%
type((df.Age > 50).values)
# Out:
# numpy.ndarray

# %%
### updating a value inside the dataframe
# replace/ update all the  age > 50 with 18
df[df.Age > 50]
# Out:
#       ID      Name   Age         Profession  salary  Marriage_proposal_count
# 3      4     Rocky  56.0               Chef  117920                        2
# 4      4     Rocky  56.0               Chef  117920                        1
# 5      4     Rocky  56.0               Chef  117920                        3
# 6      4     Rocky  56.0               Chef  117920                       11
# 7      4     Rocky  56.0               Chef  117920                        2
# ..   ...       ...   ...                ...     ...                      ...
# 489  490      John  56.0          Scientist   41192                        7
# 490  491      John  57.0              Pilot  154180                        0
# 492  493      John  55.0             Artist   57720                        2
# 498  499    Olivia  55.0           Comedian  192618                        5
# 499  500  Sherlock  59.0  Software Engineer  194886                       28
#
# [126 rows x 6 columns]

# %%
df.loc[df.Age > 50,"Age"] = 18
df
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count
# 0      1     olivia  23.0            Teacher  184518                        0
# 1      2  sophia     20.0              Boxer  119572                        2
# 2      3       jake  38.0          Scientist  174897                        1
# 3      4      Rocky  18.0               Chef  117920                        2
# 4      4      Rocky  18.0               Chef  117920                        1
# ..   ...        ...   ...                ...     ...                      ...
# 495  496       John  45.0              Boxer  137929                        0
# 496  497   Sherlock  46.0              Boxer   39870                        6
# 497  498   Sherlock  47.0          Detective  165951                        5
# 498  499     Olivia  18.0           Comedian  192618                        5
# 499  500   Sherlock  18.0  Software Engineer  194886                       28
#
# [500 rows x 6 columns]

# %%
# identify the single value
df.loc[0,"Name"] = "Rajinikanth"
df
# Out:
#       ID         Name   Age         Profession  salary  \
# 0      1  Rajinikanth  23.0            Teacher  184518
# 1      2    sophia     20.0              Boxer  119572
# 2      3         jake  38.0          Scientist  174897
# 3      4        Rocky  18.0               Chef  117920
# 4      4        Rocky  18.0               Chef  117920
# ..   ...          ...   ...                ...     ...
# 495  496         John  45.0              Boxer  137929
# 496  497     Sherlock  46.0              Boxer   39870
# 497  498     Sherlock  47.0          Detective  165951
# 498  499       Olivia  18.0           Comedian  192618
# 499  500     Sherlock  18.0  Software Engineer  194886
#
#      Marriage_proposal_count
# 0                          0
# 1                          2
# 2                          1
# 3                          2
# 4                          1
# ..                       ...
# 495                        0
# 496                        6
# 497                        5
# 498                        5
# 499                       28
#
# [500 rows x 6 columns]

# %%
# using iloc change the value
df.iloc[0,1] = "Surya"
df
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count
# 0      1      Surya  23.0            Teacher  184518                        0
# 1      2  sophia     20.0              Boxer  119572                        2
# 2      3       jake  38.0          Scientist  174897                        1
# 3      4      Rocky  18.0               Chef  117920                        2
# 4      4      Rocky  18.0               Chef  117920                        1
# ..   ...        ...   ...                ...     ...                      ...
# 495  496       John  45.0              Boxer  137929                        0
# 496  497   Sherlock  46.0              Boxer   39870                        6
# 497  498   Sherlock  47.0          Detective  165951                        5
# 498  499     Olivia  18.0           Comedian  192618                        5
# 499  500   Sherlock  18.0  Software Engineer  194886                       28
#
# [500 rows x 6 columns]

# %%
### at  & iat for single value access
df.at[0, "Name"] = "Mahesh babu"
df
# Out:
#       ID         Name   Age         Profession  salary  \
# 0      1  Mahesh babu  23.0            Teacher  184518
# 1      2    sophia     20.0              Boxer  119572
# 2      3         jake  38.0          Scientist  174897
# 3      4        Rocky  18.0               Chef  117920
# 4      4        Rocky  18.0               Chef  117920
# ..   ...          ...   ...                ...     ...
# 495  496         John  45.0              Boxer  137929
# 496  497     Sherlock  46.0              Boxer   39870
# 497  498     Sherlock  47.0          Detective  165951
# 498  499       Olivia  18.0           Comedian  192618
# 499  500     Sherlock  18.0  Software Engineer  194886
#
#      Marriage_proposal_count
# 0                          0
# 1                          2
# 2                          1
# 3                          2
# 4                          1
# ..                       ...
# 495                        0
# 496                        6
# 497                        5
# 498                        5
# 499                       28
#
# [500 rows x 6 columns]

# %%
###  iat for single value access
df.iat[0, 1] = "Allu Arjun"
df
# Out:
#       ID        Name   Age         Profession  salary  Marriage_proposal_count
# 0      1  Allu Arjun  23.0            Teacher  184518                        0
# 1      2   sophia     20.0              Boxer  119572                        2
# 2      3        jake  38.0          Scientist  174897                        1
# 3      4       Rocky  18.0               Chef  117920                        2
# 4      4       Rocky  18.0               Chef  117920                        1
# ..   ...         ...   ...                ...     ...                      ...
# 495  496        John  45.0              Boxer  137929                        0
# 496  497    Sherlock  46.0              Boxer   39870                        6
# 497  498    Sherlock  47.0          Detective  165951                        5
# 498  499      Olivia  18.0           Comedian  192618                        5
# 499  500    Sherlock  18.0  Software Engineer  194886                       28
#
# [500 rows x 6 columns]

# %%
### SOrting rows in a dataframe
df.sort_values("Age")
# Out:
#       ID      Name   Age         Profession  salary  Marriage_proposal_count
# 499  500  Sherlock  18.0  Software Engineer  194886                       28
# 316  317     Alice  18.0           Comedian  102420                        0
# 309  310      John  18.0  Software Engineer  175585                        5
# 297  298      Emma  18.0          Scientist  143154                        1
# 290  291     Rocky  18.0             Doctor  166138                        5
# ..   ...       ...   ...                ...     ...                      ...
# 46    47  Mr. Bean   NaN             Artist  190559                        5
# 71    72      Emma   NaN              Pilot   49986                        3
# 72    73    Sophia   NaN             Artist   86741                        1
# 73    74     Rocky   NaN  Software Engineer  159260                        0
# 74    75  Sherlock   NaN          Detective  165463                        0
#
# [500 rows x 6 columns]

# %%
df.sort_values('Age', ascending = False)
# Out:
#       ID      Name   Age         Profession  salary  Marriage_proposal_count
# 388  389    Olivia  50.0             Doctor  155081                        1
# 105  106  Mr. Bean  50.0  Software Engineer  170907                        1
# 165  166      Emma  50.0             Doctor   88010                        4
# 283  284      Jake  50.0             Doctor  113225                        0
# 348  349    Sophia  50.0           Comedian   84575                        2
# ..   ...       ...   ...                ...     ...                      ...
# 46    47  Mr. Bean   NaN             Artist  190559                        5
# 71    72      Emma   NaN              Pilot   49986                        3
# 72    73    Sophia   NaN             Artist   86741                        1
# 73    74     Rocky   NaN  Software Engineer  159260                        0
# 74    75  Sherlock   NaN          Detective  165463                        0
#
# [500 rows x 6 columns]

# %%
df.sort_values('Name', ascending = False)
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count
# 1      2  sophia     20.0              Boxer  119572                        2
# 2      3       jake  38.0          Scientist  174897                        1
# 393  394     Sophia  46.0           Comedian  120205                        3
# 465  466     Sophia  37.0          Detective  160158                        2
# 458  459     Sophia  27.0           Comedian  114978                        4
# ..   ...        ...   ...                ...     ...                      ...
# 359  360      Alice  36.0            Teacher   56591                        0
# 152  153      Alice  18.0            Teacher   34825                        0
# 153  154      Alice  18.0              Boxer   31088                       11
# 345  346      Alice  18.0           Comedian  104236                        5
# 363  364      Alice  25.0  Software Engineer  105197                       10
#
# [500 rows x 6 columns]

# %%
# sort_index() is used to sort index of dataframe
# if we want based upon the index
df1.sort_index()
# Out:
#        Age
# 0    100.0
# 1    100.0
# 2    100.0
# 3    100.0
# 4    100.0
# ..     ...
# 495  100.0
# 496  100.0
# 497  100.0
# 498  100.0
# 499  100.0
#
# [500 rows x 1 columns]

# %%
df1.sort_index(inplace = True)
df1
# Out:
#        Age
# 0    100.0
# 1    100.0
# 2    100.0
# 3    100.0
# 4    100.0
# ..     ...
# 495  100.0
# 496  100.0
# 497  100.0
# 498  100.0
# 499  100.0
#
# [500 rows x 1 columns]

# %%
df1 = df.copy()

df1['Age'] = df1['Age'].where(df1['Age'] > 50, 100)

df1
# Out:
#       ID        Name    Age         Profession  salary  \
# 0      1  Allu Arjun  100.0            Teacher  184518
# 1      2   sophia     100.0              Boxer  119572
# 2      3        jake  100.0          Scientist  174897
# 3      4       Rocky  100.0               Chef  117920
# 4      4       Rocky  100.0               Chef  117920
# ..   ...         ...    ...                ...     ...
# 495  496        John  100.0              Boxer  137929
# 496  497    Sherlock  100.0              Boxer   39870
# 497  498    Sherlock  100.0          Detective  165951
# 498  499      Olivia  100.0           Comedian  192618
# 499  500    Sherlock  100.0  Software Engineer  194886
#
#      Marriage_proposal_count
# 0                          0
# 1                          2
# 2                          1
# 3                          2
# 4                          1
# ..                       ...
# 495                        0
# 496                        6
# 497                        5
# 498                        5
# 499                       28
#
# [500 rows x 6 columns]

# %%
df1 = df1.set_index('ID')
df1.reset_index(inplace=True)
df1
# Out:
#       ID        Name    Age         Profession  salary  \
# 0      1  Allu Arjun  100.0            Teacher  184518
# 1      2   sophia     100.0              Boxer  119572
# 2      3        jake  100.0          Scientist  174897
# 3      4       Rocky  100.0               Chef  117920
# 4      4       Rocky  100.0               Chef  117920
# ..   ...         ...    ...                ...     ...
# 495  496        John  100.0              Boxer  137929
# 496  497    Sherlock  100.0              Boxer   39870
# 497  498    Sherlock  100.0          Detective  165951
# 498  499      Olivia  100.0           Comedian  192618
# 499  500    Sherlock  100.0  Software Engineer  194886
#
#      Marriage_proposal_count
# 0                          0
# 1                          2
# 2                          1
# 3                          2
# 4                          1
# ..                       ...
# 495                        0
# 496                        6
# 497                        5
# 498                        5
# 499                       28
#
# [500 rows x 6 columns]

# %%
df1.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Profession', 'salary', 'Marriage_proposal_count'], dtype='object')

# %% [markdown]
# #### day 16/09/2026

# %% [markdown]
# ## 5. Handiling of Missing values(NaN/NULL)

# %%
# Def: Null/NaN values are missing values. Null is different from 0.
# If their null values in the data then wrong analysis will happen.
# EDA = Exploratary Data Analysis

# %%
# finding hte null values in dataframe
import pandas as pd
df = pd.read_excel("Excel_data.xlsx")
df
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count
# 0      1     olivia  23.0            Teacher  184518                        0
# 1      2  sophia     20.0              Boxer  119572                        2
# 2      3       jake  38.0          Scientist  174897                        1
# 3      4      Rocky  56.0               Chef  117920                        2
# 4      4      Rocky  56.0               Chef  117920                        1
# ..   ...        ...   ...                ...     ...                      ...
# 495  496       John  45.0              Boxer  137929                        0
# 496  497   Sherlock  46.0              Boxer   39870                        6
# 497  498   Sherlock  47.0          Detective  165951                        5
# 498  499     Olivia  55.0           Comedian  192618                        5
# 499  500   Sherlock  59.0  Software Engineer  194886                       28
#
# [500 rows x 6 columns]

# %%
df.isnull()
# Out:
#         ID   Name    Age  Profession  salary  Marriage_proposal_count
# 0    False  False  False       False   False                    False
# 1    False  False  False       False   False                    False
# 2    False  False  False       False   False                    False
# 3    False  False  False       False   False                    False
# 4    False  False  False       False   False                    False
# ..     ...    ...    ...         ...     ...                      ...
# 495  False  False  False       False   False                    False
# 496  False  False  False       False   False                    False
# 497  False  False  False       False   False                    False
# 498  False  False  False       False   False                    False
# 499  False  False  False       False   False                    False
#
# [500 rows x 6 columns]

# %%
# check which column have how many null values
df.isnull().sum()
# Out:
# ID                         0
# Name                       0
# Age                        8
# Profession                 0
# salary                     0
# Marriage_proposal_count    0
# dtype: int64

# %%
# records with null values
df[df.Age.isnull()]
# Out:
#     ID      Name  Age         Profession  salary  Marriage_proposal_count
# 10  11     Rocky  NaN             Doctor   75543                        5
# 11  12      Jake  NaN             Artist  174780                        5
# 45  46      Liam  NaN             Doctor   84583                        0
# 46  47  Mr. Bean  NaN             Artist  190559                        5
# 71  72      Emma  NaN              Pilot   49986                        3
# 72  73    Sophia  NaN             Artist   86741                        1
# 73  74     Rocky  NaN  Software Engineer  159260                        0
# 74  75  Sherlock  NaN          Detective  165463                        0

# %%
#
df1 = df.copy()
# delete the records which is having null values
df1= df1.dropna()
df1
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count
# 0      1     olivia  23.0            Teacher  184518                        0
# 1      2  sophia     20.0              Boxer  119572                        2
# 2      3       jake  38.0          Scientist  174897                        1
# 3      4      Rocky  56.0               Chef  117920                        2
# 4      4      Rocky  56.0               Chef  117920                        1
# ..   ...        ...   ...                ...     ...                      ...
# 495  496       John  45.0              Boxer  137929                        0
# 496  497   Sherlock  46.0              Boxer   39870                        6
# 497  498   Sherlock  47.0          Detective  165951                        5
# 498  499     Olivia  55.0           Comedian  192618                        5
# 499  500   Sherlock  59.0  Software Engineer  194886                       28
#
# [492 rows x 6 columns]

# %%
df1.shape
# Out:
# (492, 6)

# %%
df2 = df2.dropna(axis = 1)
df2
# Out:
#       ID       Name         Profession  salary  Marriage_proposal_count
# 0      1     olivia            Teacher  184518                        0
# 1      2  sophia                 Boxer  119572                        2
# 2      3       jake          Scientist  174897                        1
# 3      4      Rocky               Chef  117920                        2
# 4      4      Rocky               Chef  117920                        1
# ..   ...        ...                ...     ...                      ...
# 495  496       John              Boxer  137929                        0
# 496  497   Sherlock              Boxer   39870                        6
# 497  498   Sherlock          Detective  165951                        5
# 498  499     Olivia           Comedian  192618                        5
# 499  500   Sherlock  Software Engineer  194886                       28
#
# [500 rows x 5 columns]

# %%
df2 = df.copy()
df2 = df2.dropna(axis = 1,how = "all")
df2
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count
# 0      1     olivia  23.0            Teacher  184518                        0
# 1      2  sophia     20.0              Boxer  119572                        2
# 2      3       jake  38.0          Scientist  174897                        1
# 3      4      Rocky  56.0               Chef  117920                        2
# 4      4      Rocky  56.0               Chef  117920                        1
# ..   ...        ...   ...                ...     ...                      ...
# 495  496       John  45.0              Boxer  137929                        0
# 496  497   Sherlock  46.0              Boxer   39870                        6
# 497  498   Sherlock  47.0          Detective  165951                        5
# 498  499     Olivia  55.0           Comedian  192618                        5
# 499  500   Sherlock  59.0  Software Engineer  194886                       28
#
# [500 rows x 6 columns]

# %%
df2 = df.copy()
# delete the column with null value
# how = "any" : if even a single value is null then delete the column
# how = "all" : delete column only if alll values in the column is NULL
df2 = df2.dropna(axis = 1,how = "any")
df2
# Out:
#       ID       Name         Profession  salary  Marriage_proposal_count
# 0      1     olivia            Teacher  184518                        0
# 1      2  sophia                 Boxer  119572                        2
# 2      3       jake          Scientist  174897                        1
# 3      4      Rocky               Chef  117920                        2
# 4      4      Rocky               Chef  117920                        1
# ..   ...        ...                ...     ...                      ...
# 495  496       John              Boxer  137929                        0
# 496  497   Sherlock              Boxer   39870                        6
# 497  498   Sherlock          Detective  165951                        5
# 498  499     Olivia           Comedian  192618                        5
# 499  500   Sherlock  Software Engineer  194886                       28
#
# [500 rows x 5 columns]

# %%
# replacing the null values with some other value 
df3 = df.copy()
df3.Age = df3.Age.fillna(18)
df3.isnull().sum()
# Out:
# ID                         0
# Name                       0
# Age                        0
# Profession                 0
# salary                     0
# Marriage_proposal_count    0
# dtype: int64

# %% [markdown]
# # Finding & Handling duplicate values

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
# finding number of duplicate records
df.duplicated().sum()
# Out:
# 3

# %%
# Showing 2nd and more duplicate
# complete record is matching with other record
df[df.duplicated()]
# Out:
#    ID   Name   Age Profession  salary  Marriage_proposal_count
# 7   4  Rocky  56.0       Chef  117920                        2
# 8   4  Rocky  56.0       Chef  117920                        2
# 9   4  Rocky  56.0       Chef  117920                        3

# %%
df[df.duplicated(keep = False)]
# Out:
#    ID   Name   Age Profession  salary  Marriage_proposal_count
# 3   4  Rocky  56.0       Chef  117920                        2
# 5   4  Rocky  56.0       Chef  117920                        3
# 7   4  Rocky  56.0       Chef  117920                        2
# 8   4  Rocky  56.0       Chef  117920                        2
# 9   4  Rocky  56.0       Chef  117920                        3

# %%
# finding duplicates based upon specific columns
# Query : Count all the records where age & salary is matching/duplicate
df[df.duplicated(subset = ['Name', 'Profession', 'salary'])]
# Out:
#     ID      Name   Age Profession  salary  Marriage_proposal_count
# 4    4     Rocky  56.0       Chef  117920                        1
# 5    4     Rocky  56.0       Chef  117920                        3
# 6    4     Rocky  56.0       Chef  117920                       11
# 7    4     Rocky  56.0       Chef  117920                        2
# 8    4     Rocky  56.0       Chef  117920                        2
# 9    4     Rocky  56.0       Chef  117920                        3
# 20  21  Sherlock  40.0  Detective  118998                       13
# 22  23      John  41.0  Scientist  175925                        4
# 29  30     Alice  21.0       Chef   84792                        3

# %%
# Query : Count all the records where age & salary is matching/duplicate
df[df.duplicated(keep = False , subset = ['Name', 'salary'])]
# Out:
#     ID      Name   Age Profession  salary  Marriage_proposal_count
# 3    4     Rocky  56.0       Chef  117920                        2
# 4    4     Rocky  56.0       Chef  117920                        1
# 5    4     Rocky  56.0       Chef  117920                        3
# 6    4     Rocky  56.0       Chef  117920                       11
# 7    4     Rocky  56.0       Chef  117920                        2
# 8    4     Rocky  56.0       Chef  117920                        2
# 9    4     Rocky  56.0       Chef  117920                        3
# 19  20  Sherlock  40.0  Detective  118998                        1
# 20  21  Sherlock  40.0  Detective  118998                       13
# 21  22      John  41.0  Scientist  175925                        0
# 22  23      John  41.0  Scientist  175925                        4
# 28  29     Alice  21.0       Chef   84792                        3
# 29  30     Alice  21.0       Chef   84792                        3

# %%
df[df.duplicated(keep = False , subset = ['Name', 'salary'])].count()
# Out:
# ID                         13
# Name                       13
# Age                        13
# Profession                 13
# salary                     13
# Marriage_proposal_count    13
# dtype: int64

# %%
# deleting duplicate values
df4 = df.copy()
df4 = df4.drop_duplicates()
df4.duplicated().sum()
# Out:
# 0

# %%
df4.shape
# Out:
# (497, 6)

# %%
# delete specific column based duplicate records
df5 = df.copy()
df5 = df5.drop_duplicates(subset = ['Age', 'salary'])
df5.shape
# Out:
# (491, 6)

# %%
df.duplicated(subset = ['Age', 'salary']).sum()
# Out:
# 9

# %% [markdown]
# # Handling the inconsistant data

# %%
df

# %%
# in our dataset, name of the columns are inconsistant
# lets all the column name start with capital letter
df.columns = df.columns.str.title()
df.columns
# Out:
# Index(['Id', 'Name', 'Age', 'Profession', 'Salary', 'Marriage_Proposal_Count'], dtype='object')

# %%
df.Name.unique()
# Out:
# array(['olivia', 'sophia   ', 'jake', 'Rocky', 'Jake', 'Olivia', 'John',
#        'Sherlock', 'Alice', 'Mr. Bean', 'Sophia', 'Liam', 'Emma'],
#       dtype=object)

# %%
df.Name = df.Name.str.title() 
df.Name.unique()
# Out:
# array(['Olivia', 'Sophia   ', 'Jake', 'Rocky', 'John', 'Sherlock',
#        'Alice', 'Mr. Bean', 'Sophia', 'Liam', 'Emma'], dtype=object)

# %%
df.Name = df.Name.str.strip()
df.Name.unique()
# Out:
# array(['Olivia', 'Sophia', 'Jake', 'Rocky', 'John', 'Sherlock', 'Alice',
#        'Mr. Bean', 'Liam', 'Emma'], dtype=object)

# %%
df.Profession.unique()
# Out:
# array(['Teacher', 'Boxer', 'Scientist', 'Chef', 'Doctor', 'Artist',
#        'Comedian', 'Software Engineer', 'Detective', 'Pilot'],
#       dtype=object)

# %%
df.Profession =df.Profession.str.strip()

# %%
import pandas as pd 
df = pd.read_excel("Excel_data.xlsx")
df
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count
# 0      1     olivia  23.0            Teacher  184518                        0
# 1      2  sophia     20.0              Boxer  119572                        2
# 2      3       jake  38.0          Scientist  174897                        1
# 3      4      Rocky  56.0               Chef  117920                        2
# 4      4      Rocky  56.0               Chef  117920                        1
# ..   ...        ...   ...                ...     ...                      ...
# 495  496       John  45.0              Boxer  137929                        0
# 496  497   Sherlock  46.0              Boxer   39870                        6
# 497  498   Sherlock  47.0          Detective  165951                        5
# 498  499     Olivia  55.0           Comedian  192618                        5
# 499  500   Sherlock  59.0  Software Engineer  194886                       28
#
# [500 rows x 6 columns]

# %% [markdown]
# # Data transformation using apply() & map()

# %%
# Query : double the salry of the employess
df6 = df.copy()
df6.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Profession', 'salary', 'Marriage_proposal_count'], dtype='object')

# %%
df6 = df.copy()
df6
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count
# 0      1     olivia  23.0            Teacher  184518                        0
# 1      2  sophia     20.0              Boxer  119572                        2
# 2      3       jake  38.0          Scientist  174897                        1
# 3      4      Rocky  56.0               Chef  117920                        2
# 4      4      Rocky  56.0               Chef  117920                        1
# ..   ...        ...   ...                ...     ...                      ...
# 495  496       John  45.0              Boxer  137929                        0
# 496  497   Sherlock  46.0              Boxer   39870                        6
# 497  498   Sherlock  47.0          Detective  165951                        5
# 498  499     Olivia  55.0           Comedian  192618                        5
# 499  500   Sherlock  59.0  Software Engineer  194886                       28
#
# [500 rows x 6 columns]

# %% [markdown]
# ## 17/09/2026

# %%
# Query : double the salry of the employess
df6 = df.copy()
df6.salary = df6.salary.apply(lambda x : x * 2)
df6
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count
# 0      1     olivia  23.0            Teacher  369036                        0
# 1      2  sophia     20.0              Boxer  239144                        2
# 2      3       jake  38.0          Scientist  349794                        1
# 3      4      Rocky  56.0               Chef  235840                        2
# 4      4      Rocky  56.0               Chef  235840                        1
# ..   ...        ...   ...                ...     ...                      ...
# 495  496       John  45.0              Boxer  275858                        0
# 496  497   Sherlock  46.0              Boxer   79740                        6
# 497  498   Sherlock  47.0          Detective  331902                        5
# 498  499     Olivia  55.0           Comedian  385236                        5
# 499  500   Sherlock  59.0  Software Engineer  389772                       28
#
# [500 rows x 6 columns]

# %%
# example-3: Apply() function
# Query : create a new column which is having salary / age
# Motive : use of apply() function  an complete data frame and acess multiple columns
df6["Salary_per_year_age"] = df6.apply(lambda row: row['salary']/row['Age'],axis = 1)
df6
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count  \
# 0      1     olivia  23.0            Teacher  369036                        0
# 1      2  sophia     20.0              Boxer  239144                        2
# 2      3       jake  38.0          Scientist  349794                        1
# 3      4      Rocky  56.0               Chef  235840                        2
# 4      4      Rocky  56.0               Chef  235840                        1
# ..   ...        ...   ...                ...     ...                      ...
# 495  496       John  45.0              Boxer  275858                        0
# 496  497   Sherlock  46.0              Boxer   79740                        6
# 497  498   Sherlock  47.0          Detective  331902                        5
# 498  499     Olivia  55.0           Comedian  385236                        5
# 499  500   Sherlock  59.0  Software Engineer  389772                       28
#
#      Salary_per_year_age
# 0           16045.043478
# 1           11957.200000
# 2            9205.105263
# 3            4211.428571
# 4            4211.428571
# ..                   ...
# 495          6130.177778
# 496          1733.478261
# 497          7061.744681
# 498          7004.290909
# 499          6606.305085
#
# [500 rows x 7 columns]

# %% [markdown]
# # map()

# %%
# Def: map() is used for element-wise transformation just like apply()
# example-1
df7 = df.copy()
# Query: convert all the strings in uppercase
df7.Name = df7.Name.map(lambda val : str(val).upper())
df7
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count
# 0      1     OLIVIA  23.0            Teacher  184518                        0
# 1      2  SOPHIA     20.0              Boxer  119572                        2
# 2      3       JAKE  38.0          Scientist  174897                        1
# 3      4      ROCKY  56.0               Chef  117920                        2
# 4      4      ROCKY  56.0               Chef  117920                        1
# ..   ...        ...   ...                ...     ...                      ...
# 495  496       JOHN  45.0              Boxer  137929                        0
# 496  497   SHERLOCK  46.0              Boxer   39870                        6
# 497  498   SHERLOCK  47.0          Detective  165951                        5
# 498  499     OLIVIA  55.0           Comedian  192618                        5
# 499  500   SHERLOCK  59.0  Software Engineer  194886                       28
#
# [500 rows x 6 columns]

# %%
# example-2:
# Query: convert professions from english to Telugu
df.Profession.unique()
# Out:
# array(['Teacher', '      Boxer', 'Scientist', 'Chef', 'Doctor', 'Artist',
#        'Comedian', 'Software Engineer', 'Detective', 'Pilot'],
#       dtype=object)

# %%
profession_map = {
    'Teacher' : 'Saarr',
    'Boxer' : 'Peddi',
    'Scientist' : 'sastravedu',
    'Chef' : 'Onetavadu',
    'Doctor' : 'Vaitedu',
    'Artist' : 'kalakar',
    'Camedian' : 'Haasya',
    'Software Engineer' : 'kuludu',
    'Defective' : 'Guptachariya',
    'Pilot' : 'Galodu'
}
df7['Prof_telugu'] = df7.Profession.map(profession_map)
df7
# Out:
#       ID       Name   Age         Profession  salary  Marriage_proposal_count  \
# 0      1     OLIVIA  23.0            Teacher  184518                        0
# 1      2  SOPHIA     20.0              Boxer  119572                        2
# 2      3       JAKE  38.0          Scientist  174897                        1
# 3      4      ROCKY  56.0               Chef  117920                        2
# 4      4      ROCKY  56.0               Chef  117920                        1
# ..   ...        ...   ...                ...     ...                      ...
# 495  496       JOHN  45.0              Boxer  137929                        0
# 496  497   SHERLOCK  46.0              Boxer   39870                        6
# 497  498   SHERLOCK  47.0          Detective  165951                        5
# 498  499     OLIVIA  55.0           Comedian  192618                        5
# 499  500   SHERLOCK  59.0  Software Engineer  194886                       28
#
#     Prof_telugu
# 0         Saarr
# 1           NaN
# 2    sastravedu
# 3     Onetavadu
# 4     Onetavadu
# ..          ...
# 495         NaN
# 496         NaN
# 497         NaN
# 498         NaN
# 499      kuludu
#
# [500 rows x 7 columns]

# %% [markdown]
# # 9. Aggregation and grouping

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       500 non-null    int64
#  1   Name                     500 non-null    object
#  2   Age                      492 non-null    float64
#  3   Profession               500 non-null    object
#  4   salary                   500 non-null    int64
#  5   Marriage_proposal_count  500 non-null    int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 23.6+ KB

# %%
# total salry
df.salary.sum()
# Out:
# 57801414

# %%
# average salary
df.salary.mean()
# Out:
# 115602.828

# %%
# medium of salary
# middle value after sorting data
# 10,20,30,40,50,60,70,80
df.salary.median()
# Out:
# 117920.0

# %%
df.Profession.mode()
# Out:
# 0    Chef
# Name: Profession, dtype: object

# %%
# category : yes,no    (# string data)
# continues: CGP,age   (# numerical data)
# destrict : id

# %%
# mode(): most frequent data
df.Profession.mode()
# Out:
# 0    Chef
# Name: Profession, dtype: object

# %%
# minimum salary : min()
df.salary.min()
# Out:
# 30164

# %%
# maximum salary : max()
df.salary.max()
# Out:
# 199529

# %%
# mode(): most frequent data
df.Profession.mode()
# Out:
# 0    Chef
# Name: Profession, dtype: object

# %%
# value_counts(): number of records related to particular category
df.Profession.value_counts()
# Out:
# Profession
# Chef                 58
# Scientist            54
#       Boxer          53
# Pilot                53
# Comedian             52
# Software Engineer    51
# Doctor               48
# Teacher              45
# Detective            45
# Artist               41
# Name: count, dtype: int64

# %%
# count(): count the NaN-NULL values
df.count()
# Out:
# ID                         500
# Name                       500
# Age                        492
# Profession                 500
# salary                     500
# Marriage_proposal_count    500
# dtype: int64

# %%
df.isnull().sum()
# Out:
# ID                         0
# Name                       0
# Age                        8
# Profession                 0
# salary                     0
# Marriage_proposal_count    0
# dtype: int64

# %%
# goupby(): group the data  based upon category
df.groupby('Profession').count()
# Out:
#                    ID  Name  Age  salary  Marriage_proposal_count
# Profession
#       Boxer        53    53   53      53                       53
# Artist             41    41   38      41                       41
# Chef               58    58   58      58                       58
# Comedian           52    52   52      52                       52
# Detective          45    45   44      45                       45
# Doctor             48    48   46      48                       48
# Pilot              53    53   52      53                       53
# Scientist          54    54   54      54                       54
# Software Engineer  51    51   50      51                       51
# Teacher            45    45   45      45                       45

# %%
df.groupby('Profession').Name.count()
# Out:
# Profession
#       Boxer          53
# Artist               41
# Chef                 58
# Comedian             52
# Detective            45
# Doctor               48
# Pilot                53
# Scientist            54
# Software Engineer    51
# Teacher              45
# Name: Name, dtype: int64

# %%
# find average salary based upon profession
df.groupby('Profession').salary.mean()
# Out:
# Profession
#       Boxer          103895.867925
# Artist               124550.756098
# Chef                 110806.620690
# Comedian             122689.000000
# Detective            120964.977778
# Doctor               113964.333333
# Pilot                108641.471698
# Scientist            126669.481481
# Software Engineer    117908.941176
# Teacher              107922.711111
# Name: salary, dtype: float64

# %%
df.groupby('Age').salary.mean()
# Out:
# Age
# 20.0    107930.300000
# 21.0    111202.666667
# 22.0    123330.000000
# 23.0    106353.875000
# 24.0     96071.000000
# 25.0    118117.956522
# 26.0    105049.545455
# 27.0    121657.000000
# 28.0    115759.727273
# 29.0    106755.333333
# 30.0    126964.785714
# 31.0    142756.833333
# 32.0    126444.230769
# 33.0    130019.428571
# 34.0    114673.000000
# 35.0     78758.000000
# 36.0    124278.777778
# 37.0    113419.230769
# 38.0    137063.000000
# 39.0    103876.769231
# 40.0    108059.400000
# 41.0    120925.900000
# 42.0    106310.411765
# 43.0     94403.111111
# 44.0    126647.916667
# 45.0    127032.428571
# 46.0     96160.705882
# 47.0    106546.000000
# 48.0    113052.785714
# 49.0    117906.090909
# 50.0    130377.857143
# 51.0    115272.333333
# 52.0    141711.333333
# 53.0     99333.500000
# 54.0    129167.846154
# 55.0    122092.700000
# 56.0     97167.714286
# 57.0    125854.052632
# 58.0    111681.090909
# 59.0    115163.000000
# 60.0    114066.666667
# Name: salary, dtype: float64

# %%
# agg(): can apply multiple aggregate function together an data

df[["Age", "salary"]].agg(["mean", "sum","min", "max"])
# Out:
#                Age        salary
# mean     40.810976  1.156028e+05
# sum   20079.000000  5.780141e+07
# min      20.000000  3.016400e+04
# max      60.000000  1.995290e+05

# %%
# apply different aggregate functions an different columns
df.agg({
    "Age": ["min","max"],
    "salary":["mean", "min"]
})
# Out:
#        Age      salary
# min   20.0   30164.000
# max   60.0         NaN
# mean   NaN  115602.828

# %%
# groupby() + agg()
df.groupby("Profession").agg({
    "Age": ["min","max"],
    "salary":["mean", "min"]
})
# Out:
#                     Age               salary
#                     min   max           mean    min
# Profession
#       Boxer        20.0  58.0  103895.867925  30976
# Artist             20.0  60.0  124550.756098  32961
# Chef               20.0  60.0  110806.620690  30164
# Comedian           20.0  60.0  122689.000000  32354
# Detective          20.0  60.0  120964.977778  30971
# Doctor             22.0  60.0  113964.333333  31209
# Pilot              20.0  60.0  108641.471698  31129
# Scientist          22.0  60.0  126669.481481  30659
# Software Engineer  21.0  60.0  117908.941176  30407
# Teacher            20.0  60.0  107922.711111  31162

# %% [markdown]
# ## 18/09/2026

# %% [markdown]
# # Merge two dataframes

# %%
import pandas as pd

# %%
# DEF: Merge two dataframes based upon common column.
# functions used for merging dataframes : merge(), join(), concat()

# %%
# Merge() function
df1 = pd.DataFrame({'ID' : [1,2,3], 'DreamCompany' : ["Goggle","Nvidia", "Accenture"],"Role" : ["DA", "DS", "TL"]})
df2 = pd.DataFrame({"ID" : [2,3,4], 'DreamPackage' : [20,24,50]})
print(df1)
print(df2)
# Out:
#    ID DreamCompany Role
# 0   1       Goggle   DA
# 1   2       Nvidia   DS
# 2   3    Accenture   TL
#    ID  DreamPackage
# 0   2            20
# 1   3            24
# 2   4            50

# %%
# Merge() function behaves like joins in SQL
# by default , merge() function  perform inner join  like operation 
# inner merge : common records from both the data frames
merge_df = pd.merge(df1,df2, on = "ID")
merge_df
# Out:
#    ID DreamCompany  DreamPackage
# 0   2       Nvidia            20
# 1   3    Accenture            24

# %%
merge_df = pd.merge(df1,df2, on = "ID", how = "inner")
merge_df
# Out:
#    ID DreamCompany Role  DreamPackage
# 0   2       Nvidia   DS            20
# 1   3    Accenture   TL            24

# %%
# left merge : Pick all records from left table and common records from the Right table
merge_df = pd.merge(df1,df2, on = "ID", how = "left")
merge_df
# Out:
#    ID DreamCompany Role  DreamPackage
# 0   1       Goggle   DA           NaN
# 1   2       Nvidia   DS          20.0
# 2   3    Accenture   TL          24.0

# %%
# right merge : Pick all records from right table and common records from the left table
merge_df = pd.merge(df1,df2, on = "ID", how = "right")
merge_df
# Out:
#    ID DreamCompany Role  DreamPackage
# 0   2       Nvidia   DS            20
# 1   3    Accenture   TL            24
# 2   4          NaN  NaN            50

# %%
# outer merge : Pick all records from right table and left table
# common records records will be consider one time only
merge_df = pd.merge(df1,df2, on = "ID", how = "outer")
merge_df
# Out:
#    ID DreamCompany Role  DreamPackage
# 0   1       Goggle   DA           NaN
# 1   2       Nvidia   DS          20.0
# 2   3    Accenture   TL          24.0
# 3   4          NaN  NaN          50.0

# %% [markdown]
# ## join ()

# %%
# used to join mainly based upon the index value

# %%
df3 = pd.DataFrame({"Name_richest" : ["Ambani", "Elon", "Niranjan", "Larry"]},index = [10,20,30,40])
df3
# Out:
#    Name_richest
# 10       Ambani
# 20         Elon
# 30     Niranjan
# 40        Larry

# %%
df3 = pd.DataFrame({"Name_richest" : ["Ambani", "Elon", "Niranjan", "Larry"]},index = [10,20,30,40])
df4 = pd.DataFrame({"Networth" : [10,15,500,2]}, index =[20, 30, 40, 50])
joined_df = df3.join(df4,how ="inner")
joined_df
# Out:
#    Name_richest  Networth
# 20         Elon        10
# 30     Niranjan        15
# 40        Larry       500

# %%
joined_df = df3.join(df4,how ="left")
joined_df
# Out:
#    Name_richest  Networth
# 10       Ambani       NaN
# 20         Elon      10.0
# 30     Niranjan      15.0
# 40        Larry     500.0

# %%
joined_df = df3.join(df4,how ="right")
joined_df
# Out:
#    Name_richest  Networth
# 20         Elon        10
# 30     Niranjan        15
# 40        Larry       500
# 50          NaN         2

# %%
joined_df = df3.join(df4,how ="outer")
joined_df
# Out:
#    Name_richest  Networth
# 10       Ambani       NaN
# 20         Elon      10.0
# 30     Niranjan      15.0
# 40        Larry     500.0
# 50          NaN       2.0

# %% [markdown]
# ## Concat()

# %%
# Concat() merge the dataframes veretically and horzontally
# axis = 0 -> concatinating Vertically (increase the ROWS)
# axis = 1 -> concatinating Horizontally (add columns)

# %%
df5 = pd.DataFrame({"ID" : [1,2], "Movie" : ["kobbari matta", "Paradise"]})
df6 = pd.DataFrame({"ID" : [3,4], "Movie" : ["Titanic", "spiderman"]})
df5
# Out:
#    ID          Movie
# 0   1  kobbari matta
# 1   2       Paradise

# %%
df5 = pd.DataFrame({"ID" : [1,2], "Movie" : ["kobbari matta", "Paradise"]})
df6 = pd.DataFrame({"ID" : [3,4], "Movie" : ["Titanic", "spiderman"]})
concat_df = pd.concat([df5, df6], axis = 0)
concat_df
# Out:
#    ID          Movie
# 0   1  kobbari matta
# 1   2       Paradise
# 0   3        Titanic
# 1   4      spiderman

# %%
df5 = pd.DataFrame({"ID" : [1,2], "Movie" : ["kobbari matta", "Paradise"]})
df6 = pd.DataFrame({"ID" : [3,4], "Movie" : ["Titanic", "spiderman"]})
df7 = pd.DataFrame({"ID" : [5,6], "Movie" : ["Dhurander", "Kalank"]})
concat_df = pd.concat([df5, df6,df7], axis = 1) 
concat_df
# Out:
#    ID          Movie  ID      Movie  ID      Movie
# 0   1  kobbari matta   3    Titanic   5  Dhurander
# 1   2       Paradise   4  spiderman   6     Kalank

# %%
df5 = pd.DataFrame({"ID" : [1,2], "Movie" : ["kobbari matta", "Paradise"]})
df6 = pd.DataFrame({"ID" : [3,4], "Movie" : ["Titanic", "spiderman"]})
df7 = pd.DataFrame({"ID" : [5,6], "Movie" : ["Dhurander", "Kalank"]})
concat_df = pd.concat([df5, df6,df7], axis = 0)
concat_df
# Out:
#    ID          Movie
# 0   1  kobbari matta
# 1   2       Paradise
# 0   3        Titanic
# 1   4      spiderman
# 0   5      Dhurander
# 1   6         Kalank

# %%
df5 = pd.DataFrame({"ID" : [1,2], "Movie" : ["kobbari matta", "Paradise"]})
df6 = pd.DataFrame({"ID" : [3,4], "Movie" : ["Titanic", "spiderman"]})
concat_df = pd.concat([df5, df6], axis = 0, ignore_index = True)
concat_df
# Out:
#    ID          Movie
# 0   1  kobbari matta
# 1   2       Paradise
# 2   3        Titanic
# 3   4      spiderman

# %% [markdown]
# # 10. Time series operations

# %%
# These operations we performon data and time data

# %%
import pandas as pd
date_rng = pd.date_range(start = '2021-01-01', end = '2026-12-31', freq = 'h')
print(date_rng)
# Out:
# DatetimeIndex(['2021-01-01 00:00:00', '2021-01-01 01:00:00',
#                '2021-01-01 02:00:00', '2021-01-01 03:00:00',
#                '2021-01-01 04:00:00', '2021-01-01 05:00:00',
#                '2021-01-01 06:00:00', '2021-01-01 07:00:00',
#                '2021-01-01 08:00:00', '2021-01-01 09:00:00',
#                ...
#                '2026-12-30 15:00:00', '2026-12-30 16:00:00',
#                '2026-12-30 17:00:00', '2026-12-30 18:00:00',
#                '2026-12-30 19:00:00', '2026-12-30 20:00:00',
#                '2026-12-30 21:00:00', '2026-12-30 22:00:00',
#                '2026-12-30 23:00:00', '2026-12-31 00:00:00'],
#               dtype='datetime64[ns]', length=52561, freq='h')

# %%
date_rng = pd.date_range(start = '2021-01-01', end = '2026-12-31', freq = 'ME')
print(date_rng)
# Out:
# DatetimeIndex(['2021-01-31', '2021-02-28', '2021-03-31', '2021-04-30',
#                '2021-05-31', '2021-06-30', '2021-07-31', '2021-08-31',
#                '2021-09-30', '2021-10-31', '2021-11-30', '2021-12-31',
#                '2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#                '2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31',
#                '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31',
#                '2023-01-31', '2023-02-28', '2023-03-31', '2023-04-30',
#                '2023-05-31', '2023-06-30', '2023-07-31', '2023-08-31',
#                '2023-09-30', '2023-10-31', '2023-11-30', '2023-12-31',
#                '2024-01-31', '2024-02-29', '2024-03-31', '2024-04-30',
#                '2024-05-31', '2024-06-30', '2024-07-31', '2024-08-31',
#                '2024-09-30', '2024-10-31', '2024-11-30', '2024-12-31',
#                '2025-01-31', '2025-02-28', '2025-03-31', '2025-04-30',
#                '2025-05-31', '2025-06-30', '2025-07-31', '2025-08-31',
#                '2025-09-30', '2025-10-31', '2025-11-30', '2025-12-31',
#                '2026-01-31', '2026-02-28', '2026-03-31', '2026-04-30',
#                '2026-05-31', '2026-06-30', '2026-07-31', '2026-08-31',
#                '2026-09-30', '2026-10-31', '2026-11-30', '2026-12-31'],
#               dtype='datetime64[ns]', freq='ME')

# %%
date_rng = pd.date_range(start = '2021-01-01', end = '2026-12-31', freq = 'YE')
print(date_rng)
# Out:
# DatetimeIndex(['2021-12-31', '2022-12-31', '2023-12-31', '2024-12-31',
#                '2025-12-31', '2026-12-31'],
#               dtype='datetime64[ns]', freq='YE-DEC')

# %%
# pick the 1000 records only
import numpy as np
random_dates = np.random.choice(date_rng, size=min(1000, len(date_rng)), replace=False)
print(random_dates)
# Out:
# ['2023-12-31T00:00:00.000000000' '2026-12-31T00:00:00.000000000'
#  '2022-12-31T00:00:00.000000000' '2025-12-31T00:00:00.000000000'
#  '2021-12-31T00:00:00.000000000' '2024-12-31T00:00:00.000000000']

# %%
random_dates = np.random.choice(date_rng, size=1000, replace=True)
print(len(random_dates))
# Out:
# 1000

# %%
# Creating dataframe using random_dates
canteen_df = pd.DataFrame({
    'timestamp' : pd.to_datetime(random_dates),
    'order_id' : np.arange(1,1001),  # generate values from  1 to 1000 
    'food_category' : np.random.choice(["Samosa", "Egg puff", "Drinks", "Choki Choki", "Ironi_tea"],size = 1000),
    'price' : np.random.randint(10, 500, size = 1000),
    'quantity' : np.random.randint(1,5,size = 1000)})
canteen_df
# pd.to_datetime : to convert numpy array to pandas date time format
# np.arange: generate a series of elements e.g: 1, 2, 3, 4, 5.......1000
# np.random.choice: used to randomly select categorical data
# np.random.randint: used to generate random integer values
# Out:
#      timestamp  order_id food_category  price  quantity
# 0   2021-12-31         1        Samosa    356         4
# 1   2022-12-31         2        Samosa    178         1
# 2   2021-12-31         3        Drinks     90         3
# 3   2025-12-31         4     Ironi_tea    240         3
# 4   2022-12-31         5     Ironi_tea    374         1
# ..         ...       ...           ...    ...       ...
# 995 2021-12-31       996     Ironi_tea    402         4
# 996 2026-12-31       997      Egg puff    315         2
# 997 2023-12-31       998      Egg puff     74         2
# 998 2022-12-31       999   Choki Choki    216         2
# 999 2025-12-31      1000   Choki Choki    161         2
#
# [1000 rows x 5 columns]

# %% [markdown]
# #### 19/09/2026

# %%
# sort time series data based upon timestamp
canteen_df = canteen_df.sort_values('timestamp').reset_index(drop = True)
# create new columns with just, match and day
canteen_df['year'] = canteen_df.timestamp.dt.year
canteen_df['month'] = canteen_df.timestamp.dt.month
canteen_df['day'] = canteen_df.timestamp.dt.day
canteen_df['hour'] = canteen_df.timestamp.dt.hour
canteen_df['minute'] = canteen_df.timestamp.dt.minute
canteen_df['second'] = canteen_df.timestamp.dt.second
canteen_df
# Out:
#      timestamp  order_id food_category  price  quantity  year  month  day  \
# 0   2021-12-31         1        Samosa    356         4  2021     12   31
# 1   2021-12-31       847     Ironi_tea     29         2  2021     12   31
# 2   2021-12-31       354     Ironi_tea    316         3  2021     12   31
# 3   2021-12-31       351     Ironi_tea    162         4  2021     12   31
# 4   2021-12-31       346        Samosa    125         4  2021     12   31
# ..         ...       ...           ...    ...       ...   ...    ...  ...
# 995 2026-12-31       360        Drinks    293         1  2026     12   31
# 996 2026-12-31       359        Drinks    198         4  2026     12   31
# 997 2026-12-31       358   Choki Choki    220         4  2026     12   31
# 998 2026-12-31       389      Egg puff    186         2  2026     12   31
# 999 2026-12-31       500      Egg puff    330         2  2026     12   31
#
#      hour  minute  second
# 0       0       0       0
# 1       0       0       0
# 2       0       0       0
# 3       0       0       0
# 4       0       0       0
# ..    ...     ...     ...
# 995     0       0       0
# 996     0       0       0
# 997     0       0       0
# 998     0       0       0
# 999     0       0       0
#
# [1000 rows x 11 columns]

# %% [markdown]
# # 11. Data Visualization

# %%
canteen_df.groupby('year')['quantity'].sum()
# Out:
# year
# 2021    514
# 2022    398
# 2023    389
# 2024    364
# 2025    428
# 2026    419
# Name: quantity, dtype: int32

# %%
canteen_df.groupby('year')['quantity'].sum().plot(kind ='pie')
# Out:
# <Axes: ylabel='quantity'>

# %%
canteen_df.groupby('year')['quantity'].sum().plot(kind ='bar')
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# # copy in pandas

# %% [raw]
# # type of copy in pandas
# 1. df1 = df =>  giving another name to same dataframe
# 2. df2 = df.copy() => New duplicate copy of dataset : Deep COPY
#                    => store data in different memory location
# 3. SHALLOW COPY : dataset structure is different but data is common

# %%
tourist_data = pd.DataFrame({
    'Place' : ['Mumbai', 'Goa', 'Paris','Thailand'],
    'package' :[10, 50,200, 100]
})
original_data = tourist_data.copy(deep = False)
tourist_data
# Out:
#       Place  package
# 0    Mumbai       10
# 1       Goa       50
# 2     Paris      200
# 3  Thailand      100

# %%
original_data.iloc[0,1] = 20
tourist_data
# Out:
#       Place  package
# 0    Mumbai       20
# 1       Goa       50
# 2     Paris      200
# 3  Thailand      100

# %%
original_data
# Out:
#       Place  package
# 0    Mumbai       20
# 1       Goa       50
# 2     Paris      200
# 3  Thailand      100

# %%
original_data['new_col'] = 100000

# %%
original_data
# Out:
#       Place  package  new_col
# 0    Mumbai       20   100000
# 1       Goa       50   100000
# 2     Paris      200   100000
# 3  Thailand      100   100000
